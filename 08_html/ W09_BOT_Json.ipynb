# %% [markdown]
# # **BOT API apply**
#
# ให้ทำการสมัครสมาชิกของธนาคารแห่งประเทศไทย
# จากนั้นใส่ client-id ที่ได้รับ
# และทำการเชื่อมต่อข้อมูล Statistics exchange rate โดยกำหนดวันเริ่มต้นคือ 2020-08-01 วันสิ้นสุดคือ 2020-08-27 สกุลเงิน USD

# %%
import http.client

conn = http.client.HTTPSConnection("apigw1.bot.or.th")

headers = { 'X-IBM-Client-Id': "b70cba08-96de-4684-9055-a78d57f73e67" }

conn.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2020-08-01&end_period=2020-08-27&currency=USD", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"result":{"timestamp":"2023-09-03 13:43:16","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2023-09-01"},"data_detail":[{"period":"2020-08-27","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.9987000","buying_transfer":"31.0915000","selling":"31.4346000","mid_rate":"31.2631000"},{"period":"2020-08-26","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"31.1275000","buying_transfer":"31.2221000","selling":"31.5587000","mid_rate":"31.3904000"},{"period":"2020-08-25","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"31.2228000","buying_transfer":"31.3129000","selling":"31.6520000","mid_rate":"31.4825000"},{"period":"2020-08-24","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"31.2887000","buying_transfer":"31.3841000","selling":"31.7217000","mid_rate":"31.5529000"},{"period":"2020-08-21","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"31.1785000","buying_transfer":"31.2714000","selling":"31.6102000","mid_rate":"31.4408000"},{"period":"2020-08-20","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"31.1176000","buying_transfer":"31.2131000","selling":"31.5427000","mid_rate":"31.3779000"},{"period":"2020-08-19","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.9163000","buying_transfer":"31.0103000","selling":"31.3556000","mid_rate":"31.1830000"},{"period":"2020-08-18","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.9011000","buying_transfer":"30.9944000","selling":"31.3264000","mid_rate":"31.1604000"},{"period":"2020-08-17","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.8682000","buying_transfer":"30.9611000","selling":"31.3032000","mid_rate":"31.1322000"},{"period":"2020-08-14","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.7950000","buying_transfer":"30.8862000","selling":"31.2287000","mid_rate":"31.0575000"},{"period":"2020-08-13","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.7803000","buying_transfer":"30.8727000","selling":"31.2259000","mid_rate":"31.0493000"},{"period":"2020-08-11","currency_id":"USD","currency_name_th":"สหรัฐอเมริกา : ดอลลาร์ (USD)","currency_name_eng":"USA : DOLLAR (USD) ","buying_sight":"30.8464000","buying_transfer":"30.9404000","selling":"31.2828000","mid_rate":"31.1116000"},{"period":"2020-08-10","currency_id":"USD","currency_name_th":"สหรัฐอเม ...

# %% [markdown]
# #**Read json data**
# ทำการอ่านข้อมูล json ที่อ่านเข้ามาและเก็บไว้ในตัวแปร obj

# %%
import json

obj = json.loads(data)

# %% [markdown]
# # **แสดงข้อมูล obj**

# %%
obj
# Out:
# {'result': {'timestamp': '2023-09-03 13:43:16',
#   'api': 'Daily Weighted-average Interbank Exchange Rate - THB / USD',
#   'data': {'data_header': {'report_name_eng': 'Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)',
#     'report_name_th': 'อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)',
#     'report_uoq_name_eng': '(Unit: Baht / 1 Unit of Foreign Currency)',
#     'report_uoq_name_th': '(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)',
#     'report_source_of_data': [{'source_of_data_eng': 'Bank of Thailand',
#       'source_of_data_th': 'ธนาคารแห่งประเทศไทย'}],
#     'report_remark': [{'report_remark_eng': 'Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.',
#       'report_remark_th': 'ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ'}],
#     'last_updated': '2023-09-01'},
#    'data_detail': [{'period': '2020-08-27',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9987000',
#      'buying_transfer': '31.0915000',
#      'selling': '31.4346000',
#      'mid_rate': '31.2631000'},
#     {'period': '2020-08-26',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '31.1275000',
#      'buying_transfer': '31.2221000',
#      'selling': '31.5587000',
#      'mid_rate': '31.3904000'},
#     {'period': '2020-08-25',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '31.2228000',
#      'buying_transfer': '31.3129000',
#      'selling': '31.6520000',
#      'mid_rate': '31.4825000'},
#     {'period': '2020-08-24',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '31.2887000',
#      'buying_transfer': '31.3841000',
#      'selling': '31.7217000',
#      'mid_rate': '31.5529000'},
#     {'period': '2020-08-21',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '31.1785000',
#      'buying_transfer': '31.2714000',
#      'selling': '31.6102000',
#      'mid_rate': '31.4408000'},
#     {'period': '2020-08-20',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '31.1176000',
#      'buying_transfer': '31.2131000',
#      'selling': '31.5427000',
#      'mid_rate': '31.3779000'},
#     {'period': '2020-08-19',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9163000',
#      'buying_transfer': '31.0103000',
#      'selling': '31.3556000',
#      'mid_rate': '31.1830000'},
#     {'period': '2020-08-18',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9011000',
#      'buying_transfer': '30.9944000',
#      'selling': '31.3264000',
#      'mid_rate': '31.1604000'},
#     {'period': '2020-08-17',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.8682000',
#      'buying_transfer': '30.9611000',
#      'selling': '31.3032000',
#      'mid_rate': '31.1322000'},
#     {'period': '2020-08-14',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.7950000',
#      'buying_transfer': '30.8862000',
#      'selling': '31.2287000',
#      'mid_rate': '31.0575000'},
#     {'period': '2020-08-13',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.7803000',
#      'buying_transfer': '30.8727000',
#      'selling': '31.2259000',
#      'mid_rate': '31.0493000'},
#     {'period': '2020-08-11',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.8464000',
#      'buying_transfer': '30.9404000',
#      'selling': '31.2828000',
#      'mid_rate': '31.1116000'},
#     {'period': '2020-08-10',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9054000',
#      'buying_transfer': '30.9986000',
#      'selling': '31.3449000',
#      'mid_rate': '31.1718000'},
#     {'period': '2020-08-07',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9024000',
#      'buying_transfer': '30.9958000',
#      'selling': '31.3238000',
#      'mid_rate': '31.1598000'},
#     {'period': '2020-08-06',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.7839000',
#      'buying_transfer': '30.8774000',
#      'selling': '31.2110000',
#      'mid_rate': '31.0442000'},
#     {'period': '2020-08-05',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.7531000',
#      'buying_transfer': '30.8466000',
#      'selling': '31.1982000',
#      'mid_rate': '31.0224000'},
#     {'period': '2020-08-04',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.8731000',
#      'buying_transfer': '30.9679000',
#      'selling': '31.3082000',
#      'mid_rate': '31.1381000'},
#     {'period': '2020-08-03',
#      'currency_id': 'USD',
#      'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#      'currency_name_eng': 'USA : DOLLAR (USD) ',
#      'buying_sight': '30.9642000',
#      'buying_transfer': '31.0568000',
#      'selling': '31.4008000',
#      'mid_rate': '31.2288000'}]}}}

# %% [markdown]
# แสดงชนิดข้อมูลของ obj

# %%
type(obj)
# Out:
# dict

# %% [markdown]
# แสดงข้อมูลอธิบายรายละเอียดบรรทัดแรกของ obj

# %%
obj['result']['timestamp']
# Out:
# '2023-09-03 13:43:16'

# %% [markdown]
# แสดงข้อมูล data_header ของ obj

# %%
obj['result']['data']['data_header']
# Out:
# {'report_name_eng': 'Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)',
#  'report_name_th': 'อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)',
#  'report_uoq_name_eng': '(Unit: Baht / 1 Unit of Foreign Currency)',
#  'report_uoq_name_th': '(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)',
#  'report_source_of_data': [{'source_of_data_eng': 'Bank of Thailand',
#    'source_of_data_th': 'ธนาคารแห่งประเทศไทย'}],
#  'report_remark': [{'report_remark_eng': 'Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.',
#    'report_remark_th': 'ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ'}],
#  'last_updated': '2023-09-01'}

# %% [markdown]
# แสดงข้อมูล data_detail ของ obj

# %%
obj['result']['data']['data_detail']
# Out:
# [{'period': '2020-08-27',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9987000',
#   'buying_transfer': '31.0915000',
#   'selling': '31.4346000',
#   'mid_rate': '31.2631000'},
#  {'period': '2020-08-26',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '31.1275000',
#   'buying_transfer': '31.2221000',
#   'selling': '31.5587000',
#   'mid_rate': '31.3904000'},
#  {'period': '2020-08-25',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '31.2228000',
#   'buying_transfer': '31.3129000',
#   'selling': '31.6520000',
#   'mid_rate': '31.4825000'},
#  {'period': '2020-08-24',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '31.2887000',
#   'buying_transfer': '31.3841000',
#   'selling': '31.7217000',
#   'mid_rate': '31.5529000'},
#  {'period': '2020-08-21',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '31.1785000',
#   'buying_transfer': '31.2714000',
#   'selling': '31.6102000',
#   'mid_rate': '31.4408000'},
#  {'period': '2020-08-20',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '31.1176000',
#   'buying_transfer': '31.2131000',
#   'selling': '31.5427000',
#   'mid_rate': '31.3779000'},
#  {'period': '2020-08-19',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9163000',
#   'buying_transfer': '31.0103000',
#   'selling': '31.3556000',
#   'mid_rate': '31.1830000'},
#  {'period': '2020-08-18',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9011000',
#   'buying_transfer': '30.9944000',
#   'selling': '31.3264000',
#   'mid_rate': '31.1604000'},
#  {'period': '2020-08-17',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.8682000',
#   'buying_transfer': '30.9611000',
#   'selling': '31.3032000',
#   'mid_rate': '31.1322000'},
#  {'period': '2020-08-14',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.7950000',
#   'buying_transfer': '30.8862000',
#   'selling': '31.2287000',
#   'mid_rate': '31.0575000'},
#  {'period': '2020-08-13',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.7803000',
#   'buying_transfer': '30.8727000',
#   'selling': '31.2259000',
#   'mid_rate': '31.0493000'},
#  {'period': '2020-08-11',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.8464000',
#   'buying_transfer': '30.9404000',
#   'selling': '31.2828000',
#   'mid_rate': '31.1116000'},
#  {'period': '2020-08-10',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9054000',
#   'buying_transfer': '30.9986000',
#   'selling': '31.3449000',
#   'mid_rate': '31.1718000'},
#  {'period': '2020-08-07',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9024000',
#   'buying_transfer': '30.9958000',
#   'selling': '31.3238000',
#   'mid_rate': '31.1598000'},
#  {'period': '2020-08-06',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.7839000',
#   'buying_transfer': '30.8774000',
#   'selling': '31.2110000',
#   'mid_rate': '31.0442000'},
#  {'period': '2020-08-05',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.7531000',
#   'buying_transfer': '30.8466000',
#   'selling': '31.1982000',
#   'mid_rate': '31.0224000'},
#  {'period': '2020-08-04',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.8731000',
#   'buying_transfer': '30.9679000',
#   'selling': '31.3082000',
#   'mid_rate': '31.1381000'},
#  {'period': '2020-08-03',
#   'currency_id': 'USD',
#   'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)',
#   'currency_name_eng': 'USA : DOLLAR (USD) ',
#   'buying_sight': '30.9642000',
#   'buying_transfer': '31.0568000',
#   'selling': '31.4008000',
#   'mid_rate': '31.2288000'}]

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# สร้างตัวแปร info เป็นข้อมูล DataFrame เก็บข้อมูล obj

# %%
info = pd.DataFrame(obj['result']['data']['data_detail'])
print(info)
# Out:
#         period currency_id              currency_name_th    currency_name_eng  \
# 0   2020-08-27         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 1   2020-08-26         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 2   2020-08-25         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 3   2020-08-24         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 4   2020-08-21         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 5   2020-08-20         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 6   2020-08-19         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 7   2020-08-18         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 8   2020-08-17         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 9   2020-08-14         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 10  2020-08-13         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 11  2020-08-11         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 12  2020-08-10         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 13  2020-08-07         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 14  2020-08-06         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 15  2020-08-05         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 16  2020-08-04         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
# 17  2020-08-03         USD  สหรัฐอเมริกา : ดอลลาร์ (USD)  USA : DOLLAR (USD)
#
#    buying_sight buying_transfer     selling    mid_rate
# 0    30.9987000      31.0915000  31.4346000  31.2631000
# 1    31.1275000      31.2221000  31.5587000  31.3904000
# 2    31.2228000      31.3129000  31.6520000  31.4825000
# 3    31.2887000      31.3841000  31.7217000  31.5529000
# 4    31.1785000      31.2714000  31.6102000  31.4408000
# 5    31.1176000      31.2131000  31.5427000  31.3779000
# 6    30.9163000      31.0103000  31.3556000  31.1830000
# 7    30.9011000      30.9944000  31.3264000  31.1604000
# 8    30.8682000      30.9611000  31.3032000  31.1322000
# 9    30.7950000      30.8862000  31.2287000  31.0575000
# 10   30.7803000      30.8727000  31.2259000  31.0493000
# 11   30.8464000      30.9404000  31.2828000  31.1116000
# 12   30.9054000      30.9986000  31.3449000  31.1718000
# 13   30.9024000      30.9958000  31.3238000  31.1598000
# 14   30.7839000      30.8774000  31.2110000  31.0442000
# 15   30.7531000      30.8466000  31.1982000  31.0224000
# 16   30.8731000      30.9679000  31.3082000  31.1381000
# 17   30.9642000      31.0568000  31.4008000  31.2288000

# %% [markdown]
# จากข้อมูลข้างต้น info ให้ทำการสร้างตัวแปร info_detail ที่ประกอบด้วยคอลัมน์ period, currency_id, buying_sight, selling, buying_transfer และ mid_rate

# %%
info_detail = pd.DataFrame(info, columns=['period','currency_id','buying_sight', \
              'selling','buying_transfer','mid_rate'])
print(info_detail)
# Out:
#         period currency_id buying_sight     selling buying_transfer  \
# 0   2020-08-27         USD   30.9987000  31.4346000      31.0915000
# 1   2020-08-26         USD   31.1275000  31.5587000      31.2221000
# 2   2020-08-25         USD   31.2228000  31.6520000      31.3129000
# 3   2020-08-24         USD   31.2887000  31.7217000      31.3841000
# 4   2020-08-21         USD   31.1785000  31.6102000      31.2714000
# 5   2020-08-20         USD   31.1176000  31.5427000      31.2131000
# 6   2020-08-19         USD   30.9163000  31.3556000      31.0103000
# 7   2020-08-18         USD   30.9011000  31.3264000      30.9944000
# 8   2020-08-17         USD   30.8682000  31.3032000      30.9611000
# 9   2020-08-14         USD   30.7950000  31.2287000      30.8862000
# 10  2020-08-13         USD   30.7803000  31.2259000      30.8727000
# 11  2020-08-11         USD   30.8464000  31.2828000      30.9404000
# 12  2020-08-10         USD   30.9054000  31.3449000      30.9986000
# 13  2020-08-07         USD   30.9024000  31.3238000      30.9958000
# 14  2020-08-06         USD   30.7839000  31.2110000      30.8774000
# 15  2020-08-05         USD   30.7531000  31.1982000      30.8466000
# 16  2020-08-04         USD   30.8731000  31.3082000      30.9679000
# 17  2020-08-03         USD   30.9642000  31.4008000      31.0568000
#
#       mid_rate
# 0   31.2631000
# 1   31.3904000
# 2   31.4825000
# 3   31.5529000
# 4   31.4408000
# 5   31.3779000
# 6   31.1830000
# 7   31.1604000
# 8   31.1322000
# 9   31.0575000
# 10  31.0493000
# 11  31.1116000
# 12  31.1718000
# 13  31.1598000
# 14  31.0442000
# 15  31.0224000
# 16  31.1381000
# 17  31.2288000

# %% [markdown]
# จากข้อมูล info ให้ทำการ drop ข้อมูลต่อไปนี้  buying_sight, currency_id, currency_name_th,mid_rate และเก็บไว้ในตัวแปรชื่อ info2

# %%
columns = ['buying_sight','currency_id', \
           'currency_name_th','mid_rate']
info2 = info.drop(columns, axis=1)
print(info2)
# Out:
#         period    currency_name_eng buying_transfer     selling
# 0   2020-08-27  USA : DOLLAR (USD)       31.0915000  31.4346000
# 1   2020-08-26  USA : DOLLAR (USD)       31.2221000  31.5587000
# 2   2020-08-25  USA : DOLLAR (USD)       31.3129000  31.6520000
# 3   2020-08-24  USA : DOLLAR (USD)       31.3841000  31.7217000
# 4   2020-08-21  USA : DOLLAR (USD)       31.2714000  31.6102000
# 5   2020-08-20  USA : DOLLAR (USD)       31.2131000  31.5427000
# 6   2020-08-19  USA : DOLLAR (USD)       31.0103000  31.3556000
# 7   2020-08-18  USA : DOLLAR (USD)       30.9944000  31.3264000
# 8   2020-08-17  USA : DOLLAR (USD)       30.9611000  31.3032000
# 9   2020-08-14  USA : DOLLAR (USD)       30.8862000  31.2287000
# 10  2020-08-13  USA : DOLLAR (USD)       30.8727000  31.2259000
# 11  2020-08-11  USA : DOLLAR (USD)       30.9404000  31.2828000
# 12  2020-08-10  USA : DOLLAR (USD)       30.9986000  31.3449000
# 13  2020-08-07  USA : DOLLAR (USD)       30.9958000  31.3238000
# 14  2020-08-06  USA : DOLLAR (USD)       30.8774000  31.2110000
# 15  2020-08-05  USA : DOLLAR (USD)       30.8466000  31.1982000
# 16  2020-08-04  USA : DOLLAR (USD)       30.9679000  31.3082000
# 17  2020-08-03  USA : DOLLAR (USD)       31.0568000  31.4008000

# %% [markdown]
# แสดงรายการข้อมูล info_detail 5 รายการแรก

# %%
info_detail.head()
# Out:
#        period currency_id buying_sight     selling buying_transfer    mid_rate
# 0  2020-08-27         USD   30.9987000  31.4346000      31.0915000  31.2631000
# 1  2020-08-26         USD   31.1275000  31.5587000      31.2221000  31.3904000
# 2  2020-08-25         USD   31.2228000  31.6520000      31.3129000  31.4825000
# 3  2020-08-24         USD   31.2887000  31.7217000      31.3841000  31.5529000
# 4  2020-08-21         USD   31.1785000  31.6102000      31.2714000  31.4408000

# %% [markdown]
# แสดงรายการข้อมูล info_detail 5 รายการท้ายสุด

# %%
info_detail.tail()
# Out:
#         period currency_id buying_sight     selling buying_transfer  \
# 13  2020-08-07         USD   30.9024000  31.3238000      30.9958000
# 14  2020-08-06         USD   30.7839000  31.2110000      30.8774000
# 15  2020-08-05         USD   30.7531000  31.1982000      30.8466000
# 16  2020-08-04         USD   30.8731000  31.3082000      30.9679000
# 17  2020-08-03         USD   30.9642000  31.4008000      31.0568000
#
#       mid_rate
# 13  31.1598000
# 14  31.0442000
# 15  31.0224000
# 16  31.1381000
# 17  31.2288000

# %% [markdown]
# # **Write json file**
# ให้นำข้อมูล obj write ลงไฟล์ชื่อ ex_rate.json

# %%
with open('ex_rate.json','w') as f:
  json.dump(obj,f)

# %% [markdown]
# #**Read json file**
#
# ทำการอ่านข้อมูลจากไฟล์ ex_rate.json มาใส่ไว้ใน DataFrame ชื่อ df และแสดงค่า df ที่ได้

# %%
df = pd.read_json('ex_rate.json')
print(df)
# Out:
#                                                       result
# api        Daily Weighted-average Interbank Exchange Rate...
# data       {'data_header': {'report_name_eng': 'Rates of ...
# timestamp                                2023-09-03 13:43:16

# %% [markdown]
# แสดงรายละเอียดของข้อมูล df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, api to timestamp
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   result  3 non-null      object
# dtypes: object(1)
# memory usage: 48.0+ bytes

# %% [markdown]
# แสดง index ของ df

# %%
df.index
# Out:
# Index(['api', 'data', 'timestamp'], dtype='object')

# %% [markdown]
# แสดง values ของ df

# %%
df.values
# Out:
# array([['Daily Weighted-average Interbank Exchange Rate - THB / USD'],
#        [{'data_header': {'report_name_eng': 'Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)', 'report_name_th': 'อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)', 'report_uoq_name_eng': '(Unit: Baht / 1 Unit of Foreign Currency)', 'report_uoq_name_th': '(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)', 'report_source_of_data': [{'source_of_data_eng': 'Bank of Thailand', 'source_of_data_th': 'ธนาคารแห่งประเทศไทย'}], 'report_remark': [{'report_remark_eng': 'Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.', 'report_remark_th': 'ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ'}], 'last_updated': '2023-09-01'}, 'data_detail': [{'period': '2020-08-27', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9987000', 'buying_transfer': '31.0915000', 'selling': '31.4346000', 'mid_rate': '31.2631000'}, {'period': '2020-08-26', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1275000', 'buying_transfer': '31.2221000', 'selling': '31.5587000', 'mid_rate': '31.3904000'}, {'period': '2020-08-25', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.2228000', 'buying_transfer': '31.3129000', 'selling': '31.6520000', 'mid_rate': '31.4825000'}, {'period': '2020-08-24', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.2887000', 'buying_transfer': '31.3841000', 'selling': '31.7217000', 'mid_rate': '31.5529000'}, {'period': '2020-08-21', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1785000', 'buying_transfer': '31.2714000', 'selling': '31.6102000', 'mid_rate': '31.4408000'}, {'period': '2020-08-20', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1176000', 'buying_transfer': '31.2131000', 'selling': '31.5427000', 'mid_rate': '31.3779000'}, {'period': '2020-08-19', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9163000', 'buying_transfer': '31.0103000', 'selling': '31.3556000', 'mid_rate': '31.1830000'}, {'period': '2020-08-18', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9011000', 'buying_transfer': '30.9944000', 'selling': '31.3264000', 'mid_rate': '31.1604000'}, {'period': '2020-08-17', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.8682000', 'buying_transfer': '30.9611000', 'selling': '31.3032000', 'mid_rate': '31.1322000'}, {'period': '2020-08-14', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.7950000', 'buying_transfer': '30.8862000', 'selling': '31.2287000', 'mid_rate': '31.0575000'}, {'period': '2020-08-13', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.7803000', 'buying_transfer': '30.8727000', 'selling': '31.2259000', 'mid_rate': '31.0493000'}, {'period': '2020-08-11', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.8464000', 'buying_transfer': '30.9404000', 'selling': '31.28280 ...
#        ['2023-09-03 13:43:16']], dtype=object)

# %% [markdown]
# แสดงประเภทของ df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# แปลงข้อมูล df เป็น json และ load กลับมาเป็นข้อมูล object ในตัวแปรชื่อ parsed

# %%
result = df.to_json()
parsed = json.loads(result)
print(parsed)
# Out:
# {'result': {'api': 'Daily Weighted-average Interbank Exchange Rate - THB / USD', 'data': {'data_header': {'report_name_eng': 'Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)', 'report_name_th': 'อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)', 'report_uoq_name_eng': '(Unit: Baht / 1 Unit of Foreign Currency)', 'report_uoq_name_th': '(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)', 'report_source_of_data': [{'source_of_data_eng': 'Bank of Thailand', 'source_of_data_th': 'ธนาคารแห่งประเทศไทย'}], 'report_remark': [{'report_remark_eng': 'Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.', 'report_remark_th': 'ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ'}], 'last_updated': '2023-09-01'}, 'data_detail': [{'period': '2020-08-27', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9987000', 'buying_transfer': '31.0915000', 'selling': '31.4346000', 'mid_rate': '31.2631000'}, {'period': '2020-08-26', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1275000', 'buying_transfer': '31.2221000', 'selling': '31.5587000', 'mid_rate': '31.3904000'}, {'period': '2020-08-25', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.2228000', 'buying_transfer': '31.3129000', 'selling': '31.6520000', 'mid_rate': '31.4825000'}, {'period': '2020-08-24', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.2887000', 'buying_transfer': '31.3841000', 'selling': '31.7217000', 'mid_rate': '31.5529000'}, {'period': '2020-08-21', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1785000', 'buying_transfer': '31.2714000', 'selling': '31.6102000', 'mid_rate': '31.4408000'}, {'period': '2020-08-20', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '31.1176000', 'buying_transfer': '31.2131000', 'selling': '31.5427000', 'mid_rate': '31.3779000'}, {'period': '2020-08-19', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9163000', 'buying_transfer': '31.0103000', 'selling': '31.3556000', 'mid_rate': '31.1830000'}, {'period': '2020-08-18', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.9011000', 'buying_transfer': '30.9944000', 'selling': '31.3264000', 'mid_rate': '31.1604000'}, {'period': '2020-08-17', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.8682000', 'buying_transfer': '30.9611000', 'selling': '31.3032000', 'mid_rate': '31.1322000'}, {'period': '2020-08-14', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.7950000', 'buying_transfer': '30.8862000', 'selling': '31.2287000', 'mid_rate': '31.0575000'}, {'period': '2020-08-13', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'buying_sight': '30.7803000', 'buying_transfer': '30.8727000', 'selling': '31.2259000', 'mid_rate': '31.0493000'}, {'period': '2020-08-11', 'currency_id': 'USD', 'currency_name_th': 'สหรัฐอเมริกา : ดอลลาร์ (USD)', 'currency_name_eng': 'USA : DOLLAR (USD) ', 'b ...
