# %% [markdown]
# Panutad Sirikul
#
# 650510714
#
# Lab08_01
#
# 229323 Sec 002

# %% [markdown]
# ### จงเขียนโปรแกรมเพื่อจัดดำเนินการข้อมูลประเภท Time Series ดังต่อไปนี้

# %% [markdown]
# ### a. ทำการอ่านข้อมูลหุ้นจากเว็บ yahoo finance ในช่วงวันที่ 1 ก.ค. 2022 ถึง 30 ก.ย. 2022 ของหุ้น 3 ตัวดังต่อไปนี้ TRUE, AH, PTT โดยใช้ชื่อหุ้นที่ระบุในคำสั่งคือ TRUE.BK, AH.BK และ PTT.BK ตามลำดับ

# %%
! pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # กำหนดรูปกราฟเป็นความละเอียดสูง

# %%
print(f"pandas version = {pd.__version__}")
print(f"seaborn version = {sns.__version__}")
# Out:
# pandas version = 1.5.3
# seaborn version = 0.12.2

# %% [markdown]
# #### หุ้น TRUE

# %%
# ทำการอ่านหุ้นด้วยคำสั่ง yf.download
# ข้อมูลที่ดาวน์โหลดมาด้วยคำสั่ง yf.download จะมี Date เป็น index
stock_name = "TRUE.BK"
TRUE = yf.download(stock_name, start="2022-07-01", end="2022-09-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# เขียนลงในไฟล์ .csv
TRUE.to_csv("TRUE.csv")
# ทำการระบุ index เพื่อให้ข้อมูลเป็นแบบ Time Series
df1 = pd.read_csv("TRUE.csv", parse_dates=["Date"], index_col="Date")
df1
# Out:
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2022-07-01  4.58  4.70  4.58   4.64       4.64   84961500
# 2022-07-04  4.64  4.72  4.64   4.66       4.66   43822000
# 2022-07-05  4.68  4.68  4.54   4.58       4.58   79365100
# 2022-07-06  4.58  4.62  4.54   4.58       4.58   38859200
# 2022-07-07  4.60  4.70  4.58   4.70       4.70   54928700
# ...          ...   ...   ...    ...        ...        ...
# 2022-09-23  4.96  4.96  4.90   4.92       4.92   70322400
# 2022-09-26  4.92  5.00  4.90   4.96       4.96  151817900
# 2022-09-27  5.00  5.05  4.92   4.98       4.98  152548400
# 2022-09-28  4.96  5.00  4.92   4.96       4.96  149063500
# 2022-09-29  4.96  5.00  4.94   5.00       5.00   99845700
#
# [61 rows x 6 columns]

# %% [markdown]
# #### หุ้น AH

# %%
# ทำการอ่านหุ้นด้วยคำสั่ง yf.download
# ข้อมูลที่ดาวน์โหลดมาด้วยคำสั่ง yf.download จะมี Date เป็น index
stock_name = "AH.BK"
AH = yf.download(stock_name, start="2022-07-01", end="2022-09-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# เขียนลงในไฟล์ .csv
AH.to_csv("AH.csv")
# กำหนดให้คอลัมน์ Date เป็น index เพื่อให้ข้อมูลเป็นแบบ Time Series
df2 = pd.read_csv("AH.csv")
df2 = df2.set_index("Date")
df2
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-07-01  21.799999  21.799999  21.400000  21.500000  19.852953   504700
# 2022-07-04  21.400000  21.500000  21.200001  21.200001  19.575935   426600
# 2022-07-05  21.200001  21.299999  20.299999  20.299999  18.744879  1151700
# 2022-07-06  20.000000  20.400000  19.799999  20.000000  18.467861  1184400
# 2022-07-07  20.100000  20.600000  20.000000  20.299999  18.744879   271300
# ...               ...        ...        ...        ...        ...      ...
# 2022-09-23  32.000000  32.000000  30.500000  31.000000  29.334093  2307500
# 2022-09-26  30.750000  31.000000  29.500000  29.750000  28.151266  2369500
# 2022-09-27  29.500000  30.750000  29.500000  30.000000  28.387831  2383700
# 2022-09-28  30.000000  30.250000  29.000000  30.000000  28.387831  2414000
# 2022-09-29  30.250000  30.750000  28.750000  29.250000  27.678137  2431700
#
# [61 rows x 6 columns]

# %% [markdown]
# #### หุ้น PTT

# %%
stock_name = "PTT.BK"
PTT = yf.download(stock_name, start="2022-07-01", end="2022-09-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# เขียนลงในไฟล์ .csv
PTT.to_csv("PTT.csv")
# ให้คอลัมน์ Date เป็น index เพื่อให้ข้อมูลเป็นแบบ Time Series
df3 = pd.read_csv("PTT.csv", parse_dates=["Date"], index_col="Date")
df3
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2022-07-01  34.25  34.50  34.00  34.50  32.551601  26783100
# 2022-07-04  34.50  34.50  33.75  34.25  32.315720  69448200
# 2022-07-05  34.00  34.25  33.75  34.25  32.315720  57879800
# 2022-07-06  34.00  34.25  33.50  34.00  32.079838  60256300
# 2022-07-07  34.00  35.00  33.50  34.75  32.787479  73502900
# ...           ...    ...    ...    ...        ...       ...
# 2022-09-23  37.25  37.25  37.00  37.00  34.910412  38769800
# 2022-09-26  37.00  37.25  36.50  37.00  34.910412  55859200
# 2022-09-27  36.75  37.00  36.75  36.75  34.674530  55111300
# 2022-09-28  35.25  35.50  35.00  35.00  34.234375  49151800
# 2022-09-29  35.25  35.50  34.00  34.25  33.500782  96070900
#
# [61 rows x 6 columns]

# %% [markdown]
# ### b. ทำการ upload file ข้อมูลหุ้นจำนวน 2 ตัวคือ BBL และ SCG จากไฟล์ BBL.csv และ SCG.csv ซึ่ง download ได้ใน mango.cmu.ac.th

# %%
# upload BBL.csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6581511a-ac16-4431-8d6b-6ac65e27337a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6581511a-ac16-4431-8d6b-6ac65e27337a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# parse_dates เพื่อเปลี่ยนจาก m/dd/yyyy เป็น yyyy-mm-dd
BBL = pd.read_csv("BBL.csv", parse_dates=["Date"], index_col="Date")
# drop คอลัมน์ Dividends และ Stock Splits
BBL = BBL.drop(columns=["Dividends", "Stock Splits"])
BBL
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2022-06-15  129.425872  131.822647  128.946517  130.863937  16118700
# 2022-06-16  132.302003  132.781358  128.946518  129.425873  23239400
# 2022-06-17  129.425887  130.863953  128.946532  130.384598  16386100
# 2022-06-20  129.425873  129.905228  127.987808         NaN   9680100
# 2022-06-21  129.905228  130.384583  128.946517  129.905228   3606300
# ...                ...         ...         ...         ...       ...
# 2022-10-03  131.827949  132.312611  128.435318  128.435318  20546700
# 2022-10-04  130.373966  131.827950  130.373966  130.858627   6674800
# 2022-10-05  132.312607  132.797268  131.343284  132.312607   7397800
# 2022-10-06  132.797278  134.251263  132.797278  133.766602   8968200
# 2022-10-07  134.251263  134.251263  132.797278  133.766602   3945000
#
# [79 rows x 5 columns]

# %%
# upload SCG.csv
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c88da46a-4e6f-49e2-a94a-3a23fa109736" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c88da46a-4e6f-49e2-a94a-3a23fa109736">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# parse_dates เพื่อเปลี่ยนจาก m/dd/yyyy เป็น yyyy-mm-dd
SCG = pd.read_csv("SCG.csv", parse_dates=["Date"], index_col="Date")
# drop คอลัมน์ Dividends และ Stock Splits
SCG = SCG.drop(columns=["Dividends", "Stock Splits"])
SCG
# Out:
#                 Open      High       Low     Close  Volume
# Date
# 2022-06-15  5.287206  5.386032  5.237793  5.237793  156700
# 2022-06-16  5.237794  5.336620  4.882019  4.921549  109400
# 2022-06-17  4.921549  4.990728  4.862254  4.990728   36100
# 2022-06-20  5.040141       NaN  4.921549  4.941315   37300
# 2022-06-21  4.990728  4.990728  4.921549  4.941315   30700
# ...              ...       ...       ...       ...     ...
# 2022-10-03  4.723897  4.921549  4.723897  4.802958    8900
# 2022-10-04  4.783193  4.882019  4.783193  4.842488    3700
# 2022-10-05  4.842488  4.882019  4.822723  4.842488   22400
# 2022-10-06  4.822723  4.842488  4.822723  4.822723    5900
# 2022-10-07  4.822723  4.901784  4.822723  4.882019   58900
#
# [79 rows x 5 columns]

# %% [markdown]
# ### c. จากไฟล์ราคาหุ้นแต่ละตัว ในที่นี้จะมี 5 ตัว เราจะพิจารณาค่า column เพียง 5 ค่า ได้แก่ Open, High, Low, Close และ Volume เท่านั้น จากนั้นทำการสร้าง dataFrame เพื่อเก็บข้อมูลสำหรับหุ้นแต่ละตัว โดยมี 5 columns ที่เก็บ Open, High, Close และ Volume ที่สูงที่สุดของแต่ละเดือนในช่วง 3 เดือน (ได้แก่เดือน ก.ค., ส.ค. และ ก.ย.) ขณะที่ column Low จะเก็บราคาที่ต่ำที่สุดของแต่ละเดือนในช่วง 3 เดือน
#
# #### กรณีมีข้อมูลว่างหรือ NaN ให้ข้ามค่าข้อมูลนั้นไปไม่ต้องนำมาเปรียบเทียบ
#
# #### ตัวอย่างข้อมูลใน dataFrame ที่ต้องแสดงออกมา* กรณีนี้ชื่อหุ้นที่เป็นตัวอย่างจะแตกต่างจากโจทย์

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### เดือน กรกฎาคม [July]
# #### ข้อมูลที่สูงที่สุดของ Open, High, Close และ Volume
# #### ข้อมูลที่ต่ำที่สุดของ Low

# %% [markdown]
# ##### หุ้น TRUE.csv

# %%
# drop คอลัมน์ Low และ Adj Close
find_max = TRUE.drop(columns=["Low", "Adj Close"])
# เดือน กรกฎาคม
JUL_TRUE = find_max["2022-07-01":"2022-07-31"]
# หาค่าที่สูงที่สุดของคอลัมน์ Open, High, Close และ Volume
JUL_TRUE = pd.DataFrame(JUL_TRUE.max()).transpose()
JUL_TRUE
# Out:
#    Open  High  Close        Volume
# 0  4.86  4.96   4.86  1.333731e+09

# %%
# drop ทุกคอลัมน์ยกเว้น Low
find_min = TRUE.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กรกฎาคม
find_min = find_min["2022-07-01":"2022-07-31"]
# หาค่าที่ต่ำที่สุดของ Low
find_min = pd.DataFrame(find_min.min()).transpose()
# ระบุค่าที่ต่ำที่สุดของ Low
Low = find_min["Low"].iloc[0]
find_min
# Out:
#     Low
# 0  4.26

# %%
# แทรกคอลัมน์ Low ที่บรรจุค่าต่ำที่สุด
JUL_TRUE.insert(2, "Low", Low)
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
JUL_TRUE.insert(0, "Stock", "TRUE")
JUL_TRUE
# Out:
#   Stock  Open  High   Low  Close        Volume
# 0  TRUE  4.86  4.96  4.26   4.86  1.333731e+09

# %% [markdown]
# ##### หุ้น AH.csv

# %%
# drop คอลัมน์ Low และ Adj Close
find_max = AH.drop(columns=["Low", "Adj Close"])
# เดือน กรกฎาคม
JUL_AH = find_max["2022-07-01":"2022-07-31"]
# หาค่าที่สูงที่สุดของคอลัมน์ Open, High, Close และ Volume
JUL_AH = pd.DataFrame(JUL_AH.max()).transpose()
JUL_AH
# Out:
#         Open       High  Close     Volume
# 0  21.799999  21.799999   21.5  1184400.0

# %%
# drop ทุกคอลัมน์ยกเว้น Low
find_min = AH.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กรกฎาคม
find_min = find_min["2022-07-01":"2022-07-31"]
# หาค่าที่ต่ำที่สุดของ Low
find_min = pd.DataFrame(find_min.min()).transpose()
# ระบุค่าที่ต่ำที่สุดของ Low
Low = find_min["Low"].iloc[0]
find_min
# Out:
#     Low
# 0  19.4

# %%
# แทรกคอลัมน์ Low ที่บรรจุค่าต่ำที่สุด
JUL_AH.insert(2, "Low", Low)
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
JUL_AH.insert(0, "Stock", "AH")
JUL_AH
# Out:
#   Stock       Open       High   Low  Close     Volume
# 0    AH  21.799999  21.799999  19.4   21.5  1184400.0

# %% [markdown]
# ##### หุ้น PTT.csv

# %%
# drop คอลัมน์ Low และ Adj Close
find_max = PTT.drop(columns=["Low", "Adj Close"])
# เดือน กรกฎาคม
JUL_PTT = find_max["2022-07-01":"2022-07-31"]
# หาค่าที่สูงที่สุดของคอลัมน์ Open, High, Close และ Volume
JUL_PTT = pd.DataFrame(JUL_PTT.max()).transpose()
JUL_PTT
# Out:
#     Open  High  Close      Volume
# 0  34.75  35.0  34.75  73502900.0

# %%
# drop ทุกคอลัมน์ยกเว้น Low
find_min = PTT.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กรกฎาคม
find_min = find_min["2022-07-01":"2022-07-31"]
# หาค่าที่ต่ำที่สุดของ Low
find_min = pd.DataFrame(find_min.min()).transpose()
# ระบุค่าที่ต่ำที่สุดของ Low
Low = find_min["Low"].iloc[0]
find_min
# Out:
#     Low
# 0  33.0

# %%
# แทรกคอลัมน์ Low ที่บรรจุค่าต่ำที่สุด
JUL_PTT.insert(2, "Low", Low)
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
JUL_PTT.insert(0, "Stock", "PTT")
JUL_PTT
# Out:
#   Stock   Open  High   Low  Close      Volume
# 0   PTT  34.75  35.0  33.0  34.75  73502900.0

# %% [markdown]
# ##### หุ้น BBL.csv

# %%
# drop คอลัมน์ Low
find_max = BBL.drop(columns=["Low"])
# เดือน กรกฎาคม
JUL_BBL = find_max["2022-07-01":"2022-07-31"]
# หาค่าที่สูงที่สุดของคอลัมน์ Open, High, Close และ Volume
JUL_BBL = pd.DataFrame(JUL_BBL.max()).transpose()
JUL_BBL
# Out:
#          Open        High       Close      Volume
# 0  128.467163  128.946518  128.467163  19490600.0

# %%
# drop ทุกคอลัมน์ยกเว้น Low
find_min = BBL.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน กรกฎาคม
find_min = find_min["2022-07-01":"2022-07-31"]
# หาค่าที่ต่ำที่สุดของ Low
find_min = pd.DataFrame(find_min.min()).transpose()
# ระบุค่าที่ต่ำที่สุดของ Low
Low = find_min["Low"].iloc[0]
find_min
# Out:
#           Low
# 0  119.838767

# %%
# แทรกคอลัมน์ Low ที่บรรจุค่าต่ำที่สุด
JUL_BBL.insert(2, "Low", Low)
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
JUL_BBL.insert(0, "Stock", "BBL")
JUL_BBL
# Out:
#   Stock        Open        High         Low       Close      Volume
# 0   BBL  128.467163  128.946518  119.838767  128.467163  19490600.0

# %% [markdown]
# ##### หุ้น SCG.csv

# %%
# drop คอลัมน์ Low
find_max = SCG.drop(columns=["Low"])
# เดือน กรกฎาคม
JUL_SCG = find_max["2022-07-01":"2022-07-31"]
# หาค่าที่สูงที่สุดของคอลัมน์ Open, High, Close และ Volume
JUL_SCG = pd.DataFrame(JUL_SCG.max()).transpose()
JUL_SCG
# Out:
#        Open      High     Close   Volume
# 0  5.040141  5.040141  4.990728  89900.0

# %%
# drop ทุกคอลัมน์ยกเว้น Low
find_min = SCG.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน กรกฎาคม
find_min = find_min["2022-07-01":"2022-07-31"]
# หาค่าที่ต่ำที่สุดของ Low
find_min = pd.DataFrame(find_min.min()).transpose()
# ระบุค่าที่ต่ำที่สุดของ Low
Low = find_min["Low"].iloc[0]
find_min
# Out:
#         Low
# 0  4.763427

# %%
# แทรกคอลัมน์ Low ที่บรรจุค่าต่ำที่สุด
JUL_SCG.insert(2, "Low", Low)
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
JUL_SCG.insert(0, "Stock", "SCG")
JUL_SCG
# Out:
#   Stock      Open      High       Low     Close   Volume
# 0   SCG  5.040141  5.040141  4.763427  4.990728  89900.0

# %% [markdown]
# #### เดือน สิงหาคม [August]

# %% [markdown]
# ##### หุ้น TRUE.csv

# %%
find_max = TRUE.drop(columns=["Low", "Adj Close"])
# เดือน สิงหาคม
AUG_TRUE = find_max["2022-08-01":"2022-08-31"]
AUG_TRUE = pd.DataFrame(AUG_TRUE.max()).transpose()

find_min = TRUE.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน สิงหาคม
find_min = find_min["2022-08-01":"2022-08-31"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

AUG_TRUE.insert(2, "Low", Low)
AUG_TRUE.insert(0, "Stock", "TRUE")
AUG_TRUE
# Out:
#   Stock  Open  High   Low  Close       Volume
# 0  TRUE   5.0  5.05  4.44    5.0  369917300.0

# %% [markdown]
# ##### หุ้น AH.csv

# %%
find_max = AH.drop(columns=["Low", "Adj Close"])
# เดือน สิงหาคม
AUG_AH = find_max["2022-08-01":"2022-08-31"]
AUG_AH = pd.DataFrame(AUG_AH.max()).transpose()

find_min = AH.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน สิงหาคม
find_min = find_min["2022-08-01":"2022-08-31"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

AUG_AH.insert(2, "Low", Low)
AUG_AH.insert(0, "Stock", "AH")
AUG_AH
# Out:
#   Stock  Open  High   Low  Close     Volume
# 0    AH  24.5  25.5  21.0  25.25  7495000.0

# %% [markdown]
# ##### หุ้น PTT.csv

# %%
find_max = PTT.drop(columns=["Low", "Adj Close"])
# เดือน สิงหาคม
AUG_PTT = find_max["2022-08-01":"2022-08-31"]
AUG_PTT = pd.DataFrame(AUG_PTT.max()).transpose()

find_min = PTT.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน สิงหาคม
find_min = find_min["2022-08-01":"2022-08-31"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

AUG_PTT.insert(2, "Low", Low)
AUG_PTT.insert(0, "Stock", "PTT")
AUG_PTT
# Out:
#   Stock   Open   High   Low  Close      Volume
# 0   PTT  37.75  38.25  34.5   38.0  96869700.0

# %% [markdown]
# ##### หุ้น BBL.csv

# %%
find_max = BBL.drop(columns=["Low"])
# เดือน สิงหาคม
AUG_BBL = find_max["2022-08-01":"2022-08-31"]
AUG_BBL = pd.DataFrame(AUG_BBL.max()).transpose()

find_min = BBL.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน สิงหาคม
find_min = find_min["2022-08-01":"2022-08-31"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

AUG_BBL.insert(2, "Low", Low)
AUG_BBL.insert(0, "Stock", "BBL")
AUG_BBL
# Out:
#   Stock        Open        High         Low       Close      Volume
# 0   BBL  133.260712  134.698777  125.591019  133.260712  13296900.0

# %% [markdown]
# ##### หุ้น SCG.csv

# %%
find_max = SCG.drop(columns=["Low"])
# เดือน สิงหาคม
AUG_SCG = find_max["2022-08-01":"2022-08-31"]
AUG_SCG = pd.DataFrame(AUG_SCG.max()).transpose()

find_min = SCG.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน สิงหาคม
find_min = find_min["2022-08-01":"2022-08-31"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

AUG_SCG.insert(2, "Low", Low)
AUG_SCG.insert(0, "Stock", "SCG")
AUG_SCG
# Out:
#   Stock      Open      High       Low     Close   Volume
# 0   SCG  5.040141  5.089554  4.802958  4.941315  68400.0

# %% [markdown]
# #### เดือน กันยายน [September]

# %% [markdown]
# ##### หุ้น TRUE.csv

# %%
find_max = TRUE.drop(columns=["Low", "Adj Close"])
# เดือน กันยายน
SEP_TRUE = find_max["2022-09-01":"2022-09-30"]
SEP_TRUE = pd.DataFrame(SEP_TRUE.max()).transpose()

find_min = TRUE.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กันยายน
find_min = find_min["2022-09-01":"2022-09-30"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

SEP_TRUE.insert(2, "Low", Low)
SEP_TRUE.insert(0, "Stock", "TRUE")
SEP_TRUE
# Out:
#   Stock  Open  High   Low  Close       Volume
# 0  TRUE  5.05  5.15  4.48    5.0  560530600.0

# %% [markdown]
# ##### หุ้น AH.csv

# %%
find_max = AH.drop(columns=["Low", "Adj Close"])
# เดือน กันยายน
SEP_AH = find_max["2022-09-01":"2022-09-30"]
SEP_AH = pd.DataFrame(SEP_AH.max()).transpose()

find_min = AH.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กันยายน
find_min = find_min["2022-09-01":"2022-09-30"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

SEP_AH.insert(2, "Low", Low)
SEP_AH.insert(0, "Stock", "AH")
SEP_AH
# Out:
#   Stock  Open   High   Low  Close      Volume
# 0    AH  32.0  34.25  24.6  32.25  23612400.0

# %% [markdown]
# ##### หุ้น PTT.csv

# %%
find_max = PTT.drop(columns=["Low", "Adj Close"])
# เดือน กันยายน
SEP_PTT = find_max["2022-09-01":"2022-09-30"]
SEP_PTT = pd.DataFrame(SEP_PTT.max()).transpose()

find_min = PTT.drop(columns=["Open", "High", "Close", "Adj Close", "Volume"])
# เดือน กันยายน
find_min = find_min["2022-09-01":"2022-09-30"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

SEP_PTT.insert(2, "Low", Low)
SEP_PTT.insert(0, "Stock", "PTT")
SEP_PTT
# Out:
#   Stock   Open  High   Low  Close      Volume
# 0   PTT  37.25  37.5  34.0  37.25  96082500.0

# %% [markdown]
# ##### หุ้น BBL.csv

# %%
find_max = BBL.drop(columns=["Low"])
# เดือน กันยายน
SEP_BBL = find_max["2022-09-01":"2022-09-30"]
SEP_BBL = pd.DataFrame(SEP_BBL.max()).transpose()

find_min = BBL.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน กันยายน
find_min = find_min["2022-09-01":"2022-09-30"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

SEP_BBL.insert(2, "Low", Low)
SEP_BBL.insert(0, "Stock", "BBL")
SEP_BBL
# Out:
#   Stock        Open        High         Low       Close      Volume
# 0   BBL  135.705239  136.674573  128.919983  136.189911  21756000.0

# %% [markdown]
# ##### หุ้น SCG.csv

# %%
find_max = SCG.drop(columns=["Low"])
# เดือน กันยายน
SEP_SCG = find_max["2022-09-01":"2022-09-30"]
SEP_SCG = pd.DataFrame(SEP_SCG.max()).transpose()

find_min = SCG.drop(columns=["Open", "High", "Close", "Volume"])
# เดือน กันยายน
find_min = find_min["2022-09-01":"2022-09-30"]
find_min = pd.DataFrame(find_min.min()).transpose()
Low = find_min["Low"].iloc[0]

SEP_SCG.insert(2, "Low", Low)
SEP_SCG.insert(0, "Stock", "SCG")
SEP_SCG
# Out:
#   Stock      Open      High       Low     Close   Volume
# 0   SCG  5.040141  5.040141  4.822723  4.921549  35100.0

# %% [markdown]
# #### สร้าง dataFrame

# %%
# เปลี่ยนชื่อ index ให้เป็นชื่อเดือน
JUL_TRUE = JUL_TRUE.rename({0: "July"})
JUL_AH = JUL_AH.rename({0: "July"})
JUL_PTT = JUL_PTT.rename({0: "July"})
JUL_BBL = JUL_BBL.rename({0: "July"})
JUL_SCG = JUL_SCG.rename({0: "July"})

AUG_TRUE = AUG_TRUE.rename({0: "Aug"})
AUG_AH = AUG_AH.rename({0: "Aug"})
AUG_PTT = AUG_PTT.rename({0: "Aug"})
AUG_BBL = AUG_BBL.rename({0: "Aug"})
AUG_SCG = AUG_SCG.rename({0: "Aug"})

SEP_TRUE = SEP_TRUE.rename({0: "Sep"})
SEP_AH = SEP_AH.rename({0: "Sep"})
SEP_PTT = SEP_PTT.rename({0: "Sep"})
SEP_BBL = SEP_BBL.rename({0: "Sep"})
SEP_SCG = SEP_SCG.rename({0: "Sep"})
print("Operation Completed\n[All index has been renamed]")
# Out:
# Operation Completed
# [All index has been renamed]

# %%
# เริ่มต้นด้วย หุ้น TRUE เดือน กรกฎาคม
dataFrame = JUL_TRUE
# เชื่อม row ของข้อมูลไปเรื่อยๆ
dataFrame = pd.concat([dataFrame, JUL_AH])
dataFrame = pd.concat([dataFrame, JUL_PTT])
dataFrame = pd.concat([dataFrame, JUL_BBL])
dataFrame = pd.concat([dataFrame, JUL_SCG])

dataFrame = pd.concat([dataFrame, AUG_TRUE])
dataFrame = pd.concat([dataFrame, AUG_AH])
dataFrame = pd.concat([dataFrame, AUG_PTT])
dataFrame = pd.concat([dataFrame, AUG_BBL])
dataFrame = pd.concat([dataFrame, AUG_SCG])

dataFrame = pd.concat([dataFrame, SEP_TRUE])
dataFrame = pd.concat([dataFrame, SEP_AH])
dataFrame = pd.concat([dataFrame, SEP_PTT])
dataFrame = pd.concat([dataFrame, SEP_BBL])
dataFrame = pd.concat([dataFrame, SEP_SCG])
dataFrame
# Out:
#      Stock        Open        High         Low       Close        Volume
# July  TRUE    4.860000    4.960000    4.260000    4.860000  1.333731e+09
# July    AH   21.799999   21.799999   19.400000   21.500000  1.184400e+06
# July   PTT   34.750000   35.000000   33.000000   34.750000  7.350290e+07
# July   BBL  128.467163  128.946518  119.838767  128.467163  1.949060e+07
# July   SCG    5.040141    5.040141    4.763427    4.990728  8.990000e+04
# Aug   TRUE    5.000000    5.050000    4.440000    5.000000  3.699173e+08
# Aug     AH   24.500000   25.500000   21.000000   25.250000  7.495000e+06
# Aug    PTT   37.750000   38.250000   34.500000   38.000000  9.686970e+07
# Aug    BBL  133.260712  134.698777  125.591019  133.260712  1.329690e+07
# Aug    SCG    5.040141    5.089554    4.802958    4.941315  6.840000e+04
# Sep   TRUE    5.050000    5.150000    4.480000    5.000000  5.605306e+08
# Sep     AH   32.000000   34.250000   24.600000   32.250000  2.361240e+07
# ...

# %% [markdown]
# ### d. จากหุ้นทั้ง 5 ตัว ให้ทำการเปรียบเทียบจำนวนการซื้อขาย (Volume) ในแต่ละวันของเดือนสิงหาคม จากนั้นแสดงชื่อหุ้นที่มีจำนวนการซื้อขายมากที่สุดของวันนั้นๆ ผลลัพธ์ที่ต้องแสดงคือ วันที่ ชื่อหุ้น จำนวนการซื้อขายที่มากที่สุด (1 วันจะมีเพียง 1 หุ้น) โดยเรียงจากวันที่ 1 ส.ค. 2022 ไปถึงวันที่ 31 ส.ค. 2022

# %% [markdown]
# ตัวอย่างของรูปแบบ output*
#
# ![image.png](data:image/png;base64,...)

# %%
# drop ทุกคอลัมน์ยกเว้น Volume
true = TRUE.drop(columns=["Open", "High", "Low", "Close", "Adj Close"])
true = true["2022-08-01":"2022-08-31"]
# เพิ่มคอลัมน์ ชื่อหุ้น (Stock)
true.insert(0, "Stock", "TRUE")

ah = AH.drop(columns=["Open", "High", "Low", "Close", "Adj Close"])
ah = ah["2022-08-01":"2022-08-31"]
ah.insert(0, "Stock", "AH")

ptt = PTT.drop(columns=["Open", "High", "Low", "Close", "Adj Close"])
ptt = ptt["2022-08-01":"2022-08-31"]
ptt.insert(0, "Stock", "PTT")

bbl = BBL.drop(columns=["Open", "High", "Low", "Close"])
bbl = bbl["2022-08-01":"2022-08-31"]
bbl.insert(0, "Stock", "BBL")

scg = SCG.drop(columns=["Open", "High", "Low", "Close"])
scg = scg["2022-08-01":"2022-08-31"]
scg.insert(0, "Stock", "SCG")

# %%
# เอา DataFrame มารวมกัน
diff = pd.concat([true, ah], axis=1)
diff = pd.concat([diff, ptt], axis=1)
diff = pd.concat([diff, bbl], axis=1)
diff = pd.concat([diff, scg], axis=1)
diff
# Out:
#            Stock     Volume Stock   Volume Stock    Volume Stock    Volume  \
# Date
# 2022-08-01  TRUE  112563500    AH   888000   PTT  88917000   BBL   6687000
# 2022-08-02  TRUE  366320500    AH   269800   PTT  53686100   BBL   2410900
# 2022-08-03  TRUE  369917300    AH   374400   PTT  27271900   BBL   4583600
# 2022-08-04  TRUE  125071900    AH   731100   PTT  32575400   BBL   2669200
# 2022-08-05  TRUE  366377200    AH   344400   PTT  53854700   BBL   6410800
# 2022-08-08  TRUE  180953800    AH   403100   PTT  80742100   BBL   7360000
# 2022-08-09  TRUE  143841700    AH   339300   PTT  46983100   BBL  12405300
# 2022-08-10  TRUE  149995500    AH   577100   PTT  45477700   BBL   7590700
# 2022-08-11  TRUE  154016800    AH   725200   PTT  51073400   BBL   7422500
# 2022-08-15  TRUE   94084800    AH   734800   PTT  34452500   BBL   8186700
# 2022-08-16  TRUE   67674400    AH  4267900   PTT  75762700   BBL   5521600
# ...

# %%
# จำนวนการซื้อขายที่สูงที่สุดในแต่ละวันของเดือนสิงหาคม
max_volume = diff.max(axis=1)
max_volume
# Out:
# <ipython-input-112-7d7bbe4c98a5>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_volume = diff.max(axis=1)
# Date
# 2022-08-01    112563500
# 2022-08-02    366320500
# 2022-08-03    369917300
# 2022-08-04    125071900
# 2022-08-05    366377200
# 2022-08-08    180953800
# 2022-08-09    143841700
# 2022-08-10    149995500
# 2022-08-11    154016800
# 2022-08-15     94084800
# 2022-08-16     75762700
# 2022-08-17     93546100
# 2022-08-18     45521500
# 2022-08-19     68129400
# 2022-08-22    105231700
# 2022-08-23    128632600
# 2022-08-24    146459500
# 2022-08-25    219186000
# 2022-08-26     97309300
# 2022-08-29    106077400
# 2022-08-30    124607500
# 2022-08-31     76636200
# dtype: int64

# %%
# วันที่ 1-15 TRUE มีจำนวนการซื้อขาย (Volume) มากที่สุด
p1 = true["2022-08-01":"2022-08-15"]
# วันที่ 16 PTT มีจำนวนการซื้อขาย (Volume) มากที่สุด
p2 = ptt["2022-08-16":"2022-08-16"]
# วันที่ 17 TRUE มีจำนวนการซื้อขาย (Volume) มากที่สุด
p3 = true["2022-08-17":"2022-08-17"]
# วันที่ 18 PTT มีจำนวนการซื้อขาย (Volume) มากที่สุด
p4 = ptt["2022-08-18":"2022-08-18"]
# วันที่ 19-30 TRUE มีจำนวนการซื้อขาย (Volume) มากที่สุด
p5 = true["2022-08-19":"2022-08-30"]
# วันที่ 31 PTT มีจำนวนการซื้อขาย (Volume) มากที่สุด
p6 = ptt["2022-08-31":"2022-08-31"]

# แสดงผลลัพธ์ (Output)
output = pd.concat([p1, p2])
output = pd.concat([output, p3])
output = pd.concat([output, p4])
output = pd.concat([output, p5])
output = pd.concat([output, p6])
output
# Out:
#            Stock     Volume
# Date
# 2022-08-01  TRUE  112563500
# 2022-08-02  TRUE  366320500
# 2022-08-03  TRUE  369917300
# 2022-08-04  TRUE  125071900
# 2022-08-05  TRUE  366377200
# 2022-08-08  TRUE  180953800
# 2022-08-09  TRUE  143841700
# 2022-08-10  TRUE  149995500
# 2022-08-11  TRUE  154016800
# 2022-08-15  TRUE   94084800
# 2022-08-16   PTT   75762700
# 2022-08-17  TRUE   93546100
# 2022-08-18   PTT   45521500
# 2022-08-19  TRUE   68129400
# 2022-08-22  TRUE  105231700
# 2022-08-23  TRUE  128632600
# 2022-08-24  TRUE  146459500
# 2022-08-25  TRUE  219186000
# 2022-08-26  TRUE   97309300
# 2022-08-29  TRUE  106077400
# 2022-08-30  TRUE  124607500
# 2022-08-31   PTT   76636200

# %% [markdown]
# ### e. สร้าง dataFrame เพื่อเก็บผลต่างระหว่างค่า Open และ Close คือคำนวณ (Open-Close) ของหุ้นแต่ละตัวในแต่ละวัน(ทั้ง 3 เดือน) กรณีไม่มีค่าใดค่าหนึ่ง ไม่มีค่า Open หรือค่า Low ให้เก็บค่าเป็น NaN โดยเรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022

# %% [markdown]
# #### หุ้น TRUE

# %%
# เอาข้อมูลที่ Date ยังไม่เป็น index มาจากไฟล์ .csv
fill = pd.read_csv("TRUE.csv")
# fill the missing Dates with NaN
fill.Date = pd.to_datetime(fill.Date)
fill = fill.set_index("Date").asfreq("D")

# เอาแค่คอลัมน์ Open และ Close
oc_TRUE = fill.drop(columns=["High", "Low", "Adj Close", "Volume"])
oc_TRUE = oc_TRUE["2022-07-01":"2022-09-30"]
# เพิ่มคอลัมน์ที่คำนวณผลต่างของ Open และ Close
oc_TRUE["Open-Close"] = oc_TRUE["Open"] - oc_TRUE["Close"]
# เรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022
oc_TRUE = oc_TRUE.sort_values(by=["Date"], ascending=False)
oc_TRUE
# Out:
#             Open  Close  Open-Close
# Date
# 2022-09-29  4.96   5.00       -0.04
# 2022-09-28  4.96   4.96        0.00
# 2022-09-27  5.00   4.98        0.02
# 2022-09-26  4.92   4.96       -0.04
# 2022-09-25   NaN    NaN         NaN
# ...          ...    ...         ...
# 2022-07-05  4.68   4.58        0.10
# 2022-07-04  4.64   4.66       -0.02
# 2022-07-03   NaN    NaN         NaN
# 2022-07-02   NaN    NaN         NaN
# 2022-07-01  4.58   4.64       -0.06
#
# [91 rows x 3 columns]

# %% [markdown]
# #### หุ้น AH

# %%
# เอาข้อมูลที่ Date ยังไม่เป็น index มาจากไฟล์ .csv
fill = pd.read_csv("AH.csv")
# fill the missing Dates with NaN
fill.Date = pd.to_datetime(fill.Date)
fill = fill.set_index("Date").asfreq("D")

# เอาแค่คอลัมน์ Open และ Close
oc_AH = fill.drop(columns=["High", "Low", "Adj Close", "Volume"])
oc_AH = oc_AH["2022-07-01":"2022-09-30"]
# เพิ่มคอลัมน์ที่คำนวณผลต่างของ Open และ Close
oc_AH["Open-Close"] = oc_AH["Open"] - oc_AH["Close"]
# เรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022
oc_AH = oc_AH.sort_values(by=["Date"], ascending=False)
oc_AH
# Out:
#                  Open      Close  Open-Close
# Date
# 2022-09-29  30.250000  29.250000    1.000000
# 2022-09-28  30.000000  30.000000    0.000000
# 2022-09-27  29.500000  30.000000   -0.500000
# 2022-09-26  30.750000  29.750000    1.000000
# 2022-09-25        NaN        NaN         NaN
# ...               ...        ...         ...
# 2022-07-05  21.200001  20.299999    0.900002
# 2022-07-04  21.400000  21.200001    0.199999
# 2022-07-03        NaN        NaN         NaN
# 2022-07-02        NaN        NaN         NaN
# 2022-07-01  21.799999  21.500000    0.299999
#
# [91 rows x 3 columns]

# %% [markdown]
# #### หุ้น PTT

# %%
# เอาข้อมูลที่ Date ยังไม่เป็น index มาจากไฟล์ .csv
fill = pd.read_csv("PTT.csv")
# fill the missing Dates with NaN
fill.Date = pd.to_datetime(fill.Date)
fill = fill.set_index("Date").asfreq("D")

# เอาแค่คอลัมน์ Open และ Close
oc_PTT = fill.drop(columns=["High", "Low", "Adj Close", "Volume"])
oc_PTT = oc_PTT["2022-07-01":"2022-09-30"]
# เพิ่มคอลัมน์ที่คำนวณผลต่างของ Open และ Close
oc_PTT["Open-Close"] = oc_PTT["Open"] - oc_PTT["Close"]
# เรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022
oc_PTT = oc_PTT.sort_values(by=["Date"], ascending=False)
oc_PTT
# Out:
#              Open  Close  Open-Close
# Date
# 2022-09-29  35.25  34.25        1.00
# 2022-09-28  35.25  35.00        0.25
# 2022-09-27  36.75  36.75        0.00
# 2022-09-26  37.00  37.00        0.00
# 2022-09-25    NaN    NaN         NaN
# ...           ...    ...         ...
# 2022-07-05  34.00  34.25       -0.25
# 2022-07-04  34.50  34.25        0.25
# 2022-07-03    NaN    NaN         NaN
# 2022-07-02    NaN    NaN         NaN
# 2022-07-01  34.25  34.50       -0.25
#
# [91 rows x 3 columns]

# %% [markdown]
# #### หุ้น BBL

# %%
# เอาข้อมูลที่ Date ยังไม่เป็น index มาจากไฟล์ .csv
fill = pd.read_csv("BBL.csv")
# fill the missing Dates with NaN
fill.Date = pd.to_datetime(fill.Date)
fill = fill.set_index("Date").asfreq("D")

# เอาแค่คอลัมน์ Open และ Close
oc_BBL = fill.drop(columns=["High", "Low", "Volume", "Dividends", "Stock Splits"])
oc_BBL = oc_BBL["2022-07-01":"2022-09-30"]
# เพิ่มคอลัมน์ที่คำนวณผลต่างของ Open และ Close
oc_BBL["Open-Close"] = oc_BBL["Open"] - oc_BBL["Close"]
# เรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022
oc_BBL = oc_BBL.sort_values(by=["Date"], ascending=False)
oc_BBL
# Out:
#                   Open       Close  Open-Close
# Date
# 2022-09-30  132.797268  132.312607    0.484662
# 2022-09-29  133.766602  133.766602    0.000000
# 2022-09-28  131.827957  131.827957    0.000000
# 2022-09-27  134.735927         NaN         NaN
# 2022-09-26  135.705239  134.735916    0.969323
# ...                ...         ...         ...
# 2022-07-05  127.987794  126.070374    1.917420
# 2022-07-04  128.467163  127.508453    0.958710
# 2022-07-03         NaN         NaN         NaN
# 2022-07-02         NaN         NaN         NaN
# 2022-07-01  127.987808  128.467163   -0.479355
#
# [92 rows x 3 columns]

# %% [markdown]
# #### หุ้น SCG

# %%
# เอาข้อมูลที่ Date ยังไม่เป็น index มาจากไฟล์ .csv
fill = pd.read_csv("SCG.csv")
# fill the missing Dates with NaN
fill.Date = pd.to_datetime(fill.Date)
fill = fill.set_index("Date").asfreq("D")

# เอาแค่คอลัมน์ Open และ Close
oc_SCG = fill.drop(columns=["High", "Low", "Volume", "Dividends", "Stock Splits"])
oc_SCG = oc_SCG["2022-07-01":"2022-09-30"]
# เพิ่มคอลัมน์ที่คำนวณผลต่างของ Open และ Close
oc_SCG["Open-Close"] = oc_SCG["Open"] - oc_SCG["Close"]
# เรียงวันจาก 30 ก.ย. 2022 ไป 1 ก.ค. 2022
oc_SCG = oc_SCG.sort_values(by=["Date"], ascending=False)
oc_SCG
# Out:
#                 Open     Close  Open-Close
# Date
# 2022-09-30  4.842488  4.862254   -0.019765
# 2022-09-29  4.842488  4.882019   -0.039530
# 2022-09-28  4.862254  4.842488    0.019765
# 2022-09-27  4.882019  4.901784   -0.019765
# 2022-09-26  4.842488  4.862254   -0.019765
# ...              ...       ...         ...
# 2022-07-05  4.921549  4.783193    0.138357
# 2022-07-04  4.990728  4.882019    0.108709
# 2022-07-03       NaN       NaN         NaN
# 2022-07-02       NaN       NaN         NaN
# 2022-07-01  4.941315       NaN         NaN
#
# [92 rows x 3 columns]

# %% [markdown]
# ### f. จากผลลัพธ์ข้อ e ให้สร้าง dataFrame ที่เปลี่ยนค่าผลต่างไปเป็นคำว่า up, down หรือ same ในกรณีที่ค่าผลต่างเป็นลบ, บวก หรือ 0 ตามลำดับ ถ้าค่าคือ NaN ให้แสดงเป็น NaN

# %%
import numpy as np

# %% [markdown]
# #### หุ้น TRUE

# %%
df_TRUE = oc_TRUE.drop(columns=["Open", "Close"])
# ถ้าค่าผลต่างเป็นลบใช้คำว่า up | ถ้าค่าคือ NaN ใช้คำว่า NaN
con_2 = np.where(df_TRUE["Open-Close"] < 0.00, "up", "NaN")
# ถ้าค่าผลต่างเป็นบวกใช้คำว่า down
con_1 = np.where(df_TRUE["Open-Close"] > 0.00, "down", con_2)
# ถ้าค่าผลต่างเป็น 0 ใช้คำว่า same
df_TRUE["Change"] = np.where(df_TRUE["Open-Close"] == 0.00, "same", con_1)
df_TRUE
# Out:
#             Open-Close Change
# Date
# 2022-09-29       -0.04     up
# 2022-09-28        0.00   same
# 2022-09-27        0.02   down
# 2022-09-26       -0.04     up
# 2022-09-25         NaN    NaN
# ...                ...    ...
# 2022-07-05        0.10   down
# 2022-07-04       -0.02     up
# 2022-07-03         NaN    NaN
# 2022-07-02         NaN    NaN
# 2022-07-01       -0.06     up
#
# [91 rows x 2 columns]

# %% [markdown]
# #### หุ้น AH

# %%
df_AH = oc_AH.drop(columns=["Open", "Close"])
# ถ้าค่าผลต่างเป็นลบใช้คำว่า up | ถ้าค่าคือ NaN ใช้คำว่า NaN
con_2 = np.where(df_AH["Open-Close"] < 0.00, "up", "NaN")
# ถ้าค่าผลต่างเป็นบวกใช้คำว่า down
con_1 = np.where(df_AH["Open-Close"] > 0.00, "down", con_2)
# ถ้าค่าผลต่างเป็น 0 ใช้คำว่า same
df_AH["Change"] = np.where(df_AH["Open-Close"] == 0.00, "same", con_1)
df_AH
# Out:
#             Open-Close Change
# Date
# 2022-09-29    1.000000   down
# 2022-09-28    0.000000   same
# 2022-09-27   -0.500000     up
# 2022-09-26    1.000000   down
# 2022-09-25         NaN    NaN
# ...                ...    ...
# 2022-07-05    0.900002   down
# 2022-07-04    0.199999   down
# 2022-07-03         NaN    NaN
# 2022-07-02         NaN    NaN
# 2022-07-01    0.299999   down
#
# [91 rows x 2 columns]

# %% [markdown]
# #### หุ้น PTT

# %%
df_PTT = oc_PTT.drop(columns=["Open", "Close"])
# ถ้าค่าผลต่างเป็นลบใช้คำว่า up | ถ้าค่าคือ NaN ใช้คำว่า NaN
con_2 = np.where(df_PTT["Open-Close"] < 0.00, "up", "NaN")
# ถ้าค่าผลต่างเป็นบวกใช้คำว่า down
con_1 = np.where(df_PTT["Open-Close"] > 0.00, "down", con_2)
# ถ้าค่าผลต่างเป็น 0 ใช้คำว่า same
df_PTT["Change"] = np.where(df_PTT["Open-Close"] == 0.00, "same", con_1)
df_PTT
# Out:
#             Open-Close Change
# Date
# 2022-09-29        1.00   down
# 2022-09-28        0.25   down
# 2022-09-27        0.00   same
# 2022-09-26        0.00   same
# 2022-09-25         NaN    NaN
# ...                ...    ...
# 2022-07-05       -0.25     up
# 2022-07-04        0.25   down
# 2022-07-03         NaN    NaN
# 2022-07-02         NaN    NaN
# 2022-07-01       -0.25     up
#
# [91 rows x 2 columns]

# %% [markdown]
# #### หุ้น BBL

# %%
df_BBL = oc_BBL.drop(columns=["Open", "Close"])
# ถ้าค่าผลต่างเป็นลบใช้คำว่า up | ถ้าค่าคือ NaN ใช้คำว่า NaN
con_2 = np.where(df_BBL["Open-Close"] < 0.00, "up", "NaN")
# ถ้าค่าผลต่างเป็นบวกใช้คำว่า down
con_1 = np.where(df_BBL["Open-Close"] > 0.00, "down", con_2)
# ถ้าค่าผลต่างเป็น 0 ใช้คำว่า same
df_BBL["Change"] = np.where(df_BBL["Open-Close"] == 0.00, "same", con_1)
df_BBL
# Out:
#             Open-Close Change
# Date
# 2022-09-30    0.484662   down
# 2022-09-29    0.000000   same
# 2022-09-28    0.000000   same
# 2022-09-27         NaN    NaN
# 2022-09-26    0.969323   down
# ...                ...    ...
# 2022-07-05    1.917420   down
# 2022-07-04    0.958710   down
# 2022-07-03         NaN    NaN
# 2022-07-02         NaN    NaN
# 2022-07-01   -0.479355     up
#
# [92 rows x 2 columns]

# %% [markdown]
# #### หุ้น SCG

# %%
df_SCG = oc_SCG.drop(columns=["Open", "Close"])
# ถ้าค่าผลต่างเป็นลบใช้คำว่า up | ถ้าค่าคือ NaN ใช้คำว่า NaN
con_2 = np.where(df_SCG["Open-Close"] < 0.00, "up", "NaN")
# ถ้าค่าผลต่างเป็นบวกใช้คำว่า down
con_1 = np.where(df_SCG["Open-Close"] > 0.00, "down", con_2)
# ถ้าค่าผลต่างเป็น 0 ใช้คำว่า same
df_SCG["Change"] = np.where(df_SCG["Open-Close"] == 0.00, "same", con_1)
df_SCG
# Out:
#             Open-Close Change
# Date
# 2022-09-30   -0.019765     up
# 2022-09-29   -0.039530     up
# 2022-09-28    0.019765   down
# 2022-09-27   -0.019765     up
# 2022-09-26   -0.019765     up
# ...                ...    ...
# 2022-07-05    0.138357   down
# 2022-07-04    0.108709   down
# 2022-07-03         NaN    NaN
# 2022-07-02         NaN    NaN
# 2022-07-01         NaN    NaN
#
# [92 rows x 2 columns]

# %% [markdown]
# ### g. สร้าง dataFrame เพื่อเก็บค่าเฉลี่ยของ Open และ Close ในแต่ละเดือนของหุ้น TRUE และหุ้น SCG ถ้าข้อมูลเป็น NaN จะไม่นำมารวมในการหาค่าเฉลี่ย

# %%
df_mean =

# %% [markdown]
# #### หุ้น TRUE

# %% [markdown]
# ##### เดือน กรกฎาคม [July]

# %%
mean_JUL_TRUE = TRUE.drop(columns=["High", "Low", "Adj Close", "Volume"])
mean_JUL_TRUE = mean_JUL_TRUE["2022-07-01":"2022-07-31"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_JUL_TRUE = mean_JUL_TRUE.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_JUL_TRUE["Mean"] = (mean_JUL_TRUE["Open"] + mean_JUL_TRUE["Close"])/2
mean_JUL_TRUE
# Out:
#             Open  Close  Mean
# Date
# 2022-07-01  4.58   4.64  4.61
# 2022-07-04  4.64   4.66  4.65
# 2022-07-05  4.68   4.58  4.63
# 2022-07-06  4.58   4.58  4.58
# 2022-07-07  4.60   4.70  4.65
# 2022-07-08  4.76   4.72  4.74
# 2022-07-11  4.70   4.74  4.72
# 2022-07-12  4.72   4.66  4.69
# 2022-07-14  4.64   4.68  4.66
# 2022-07-15  4.68   4.70  4.69
# 2022-07-18  4.72   4.70  4.71
# 2022-07-19  4.68   4.70  4.69
# 2022-07-20  4.72   4.86  4.79
# 2022-07-21  4.86   4.84  4.85
# 2022-07-22  4.86   4.54  4.70
# 2022-07-25  4.56   4.58  4.57
# 2022-07-26  4.58   4.60  4.59
# 2022-07-27  4.60   4.74  4.67

# %% [markdown]
# ##### เดือน สิงหาคม [August]

# %%
mean_AUG_TRUE = TRUE.drop(columns=["High", "Low", "Adj Close", "Volume"])
mean_AUG_TRUE = mean_AUG_TRUE["2022-08-01":"2022-08-31"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_AUG_TRUE = mean_AUG_TRUE.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_AUG_TRUE["Mean"] = (mean_AUG_TRUE["Open"] + mean_AUG_TRUE["Close"])/2
mean_AUG_TRUE
# Out:
#             Open  Close  Mean
# Date
# 2022-08-01  4.76   4.78  4.77
# 2022-08-02  4.76   4.90  4.83
# 2022-08-03  4.88   4.88  4.88
# 2022-08-04  4.88   4.90  4.89
# 2022-08-05  4.90   5.00  4.95
# 2022-08-08  5.00   4.96  4.98
# 2022-08-09  4.98   5.00  4.99
# 2022-08-10  4.96   5.00  4.98
# 2022-08-11  5.00   4.90  4.95
# 2022-08-15  4.92   4.96  4.94
# 2022-08-16  4.96   4.90  4.93
# 2022-08-17  4.90   4.88  4.89
# 2022-08-18  4.86   4.84  4.85
# 2022-08-19  4.84   4.86  4.85
# 2022-08-22  4.84   4.78  4.81
# 2022-08-23  4.76   4.74  4.75
# 2022-08-24  4.74   4.64  4.69
# 2022-08-25  4.62   4.58  4.60
# 2022-08-26  4.56   4.60  4.58
# 2022-08-29  4.50   4.52  4.51
# 2022-08-30  4.52   4.62  4.57
# 2022-08-31  4.60   4.56  4.58

# %% [markdown]
# ##### เดือน กันยายน [September]

# %%
mean_SEP_TRUE = TRUE.drop(columns=["High", "Low", "Adj Close", "Volume"])
mean_SEP_TRUE = mean_SEP_TRUE["2022-09-01":"2022-09-30"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_SEP_TRUE = mean_SEP_TRUE.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_SEP_TRUE["Mean"] = (mean_SEP_TRUE["Open"] + mean_SEP_TRUE["Close"])/2
mean_SEP_TRUE
# Out:
#             Open  Close   Mean
# Date
# 2022-09-01  4.54   4.50  4.520
# 2022-09-02  4.50   4.54  4.520
# 2022-09-05  4.54   4.62  4.580
# 2022-09-06  4.64   4.60  4.620
# 2022-09-07  4.60   4.70  4.650
# 2022-09-08  4.70   4.74  4.720
# 2022-09-09  4.72   4.74  4.730
# 2022-09-12  4.76   4.80  4.780
# 2022-09-13  4.82   4.92  4.870
# 2022-09-14  4.88   5.00  4.940
# 2022-09-15  4.98   4.92  4.950
# 2022-09-16  4.92   4.90  4.910
# 2022-09-19  4.92   4.84  4.880
# 2022-09-20  4.86   4.86  4.860
# 2022-09-21  5.05   4.96  5.005
# 2022-09-22  4.94   4.98  4.960
# 2022-09-23  4.96   4.92  4.940
# 2022-09-26  4.92   4.96  4.940
# 2022-09-27  5.00   4.98  4.990
# 2022-09-28  4.96   4.96  4.960
# 2022-09-29  4.96   5.00  4.980

# %% [markdown]
# #### หุ้น SCG

# %%
SCG
# Out:
#                 Open      High       Low     Close  Volume
# Date
# 2022-06-15  5.287206  5.386032  5.237793  5.237793  156700
# 2022-06-16  5.237794  5.336620  4.882019  4.921549  109400
# 2022-06-17  4.921549  4.990728  4.862254  4.990728   36100
# 2022-06-20  5.040141       NaN  4.921549  4.941315   37300
# 2022-06-21  4.990728  4.990728  4.921549  4.941315   30700
# ...              ...       ...       ...       ...     ...
# 2022-10-03  4.723897  4.921549  4.723897  4.802958    8900
# 2022-10-04  4.783193  4.882019  4.783193  4.842488    3700
# 2022-10-05  4.842488  4.882019  4.822723  4.842488   22400
# 2022-10-06  4.822723  4.842488  4.822723  4.822723    5900
# 2022-10-07  4.822723  4.901784  4.822723  4.882019   58900
#
# [79 rows x 5 columns]

# %% [markdown]
# ##### เดือน มิถุนายน [June]

# %%
mean_JUN_SCG = SCG.drop(columns=["High", "Low", "Volume"])
mean_JUN_SCG = mean_JUN_SCG["2022-06-01":"2022-06-30"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_JUN_SCG = mean_JUN_SCG.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_JUN_SCG["Mean"] = (mean_JUN_SCG["Open"] + mean_JUN_SCG["Close"])/2
mean_JUN_SCG
# Out:
#                 Open     Close      Mean
# Date
# 2022-06-15  5.287206  5.237793  5.262500
# 2022-06-16  5.237794  4.921549  5.079671
# 2022-06-17  4.921549  4.990728  4.956139
# 2022-06-20  5.040141  4.941315  4.990728
# 2022-06-21  4.990728  4.941315  4.966021
# 2022-06-22  4.941314  4.901784  4.921549
# 2022-06-23  4.901784  4.941315  4.921549
# 2022-06-24  4.862254  4.941315  4.901784
# 2022-06-27  4.990728  4.941315  4.966021
# 2022-06-29  5.089554  4.990728  5.040141
# 2022-06-30  4.990728  4.941315  4.966021

# %% [markdown]
# ##### เดือน กรกฎาคม [July]

# %%
mean_JUL_SCG = SCG.drop(columns=["High", "Low", "Volume"])
mean_JUL_SCG = mean_JUL_SCG["2022-07-01":"2022-07-31"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_JUL_SCG = mean_JUL_SCG.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_JUL_SCG["Mean"] = (mean_JUL_SCG["Open"] + mean_JUL_SCG["Close"])/2
mean_JUL_SCG
# Out:
#                 Open     Close      Mean
# Date
# 2022-07-04  4.990728  4.882019  4.936373
# 2022-07-05  4.921549  4.783193  4.852371
# 2022-07-06  4.783193  4.783193  4.783193
# 2022-07-07  4.783193  4.842488  4.812840
# 2022-07-08  4.921549  4.901784  4.911667
# 2022-07-12  4.941315  4.941315  4.941315
# 2022-07-15  4.921549  4.990728  4.956139
# 2022-07-18  4.990728  4.990728  4.990728
# 2022-07-19  4.990728  4.990728  4.990728
# 2022-07-20  4.990728  4.941315  4.966021
# 2022-07-22  4.941315  4.990728  4.966021
# 2022-07-26  5.040141  4.990728  5.015434
# 2022-07-27  4.941315  4.990728  4.966021

# %% [markdown]
# ##### เดือน สิงหาคม [August]

# %%
mean_AUG_SCG = SCG.drop(columns=["High", "Low", "Volume"])
mean_AUG_SCG = mean_AUG_SCG["2022-08-01":"2022-08-31"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_AUG_SCG = mean_AUG_SCG.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_AUG_SCG["Mean"] = (mean_AUG_SCG["Open"] + mean_AUG_SCG["Close"])/2
mean_AUG_SCG
# Out:
#                 Open     Close      Mean
# Date
# 2022-08-02  4.990728  4.941315  4.966021
# 2022-08-03  4.941314  4.882019  4.911666
# 2022-08-05  4.990728  4.941315  4.966021
# 2022-08-08  4.941315  4.941315  4.941315
# 2022-08-09  4.921549  4.901784  4.911667
# 2022-08-10  4.990728  4.921549  4.956139
# 2022-08-11  4.921549  4.941315  4.931432
# 2022-08-15  4.921549  4.882019  4.901784
# 2022-08-16  5.040141  4.842488  4.941314
# 2022-08-17  4.941314  4.882019  4.911666
# 2022-08-18  4.901784  4.842488  4.872136
# 2022-08-19  4.862254  4.862254  4.862254
# 2022-08-23  4.941315  4.862254  4.901784
# 2022-08-25  4.941314  4.901784  4.921549
# 2022-08-26  4.901784  4.901784  4.901784
# 2022-08-29  4.921549  4.882019  4.901784
# 2022-08-30  4.901784  4.921549  4.911667
# 2022-08-31  4.921549  4.901784  4.911667

# %% [markdown]
# ##### เดือน กันยายน [September]

# %%
mean_SEP_SCG = SCG.drop(columns=["High", "Low", "Volume"])
mean_SEP_SCG = mean_SEP_SCG["2022-09-01":"2022-09-30"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_SEP_SCG = mean_SEP_SCG.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_SEP_SCG["Mean"] = (mean_SEP_SCG["Open"] + mean_SEP_SCG["Close"])/2
mean_SEP_SCG
# Out:
#                 Open     Close      Mean
# Date
# 2022-09-01  5.040141  4.921549  4.980845
# 2022-09-02  4.921549  4.882019  4.901784
# 2022-09-05  4.901784  4.901784  4.901784
# 2022-09-06  4.882019  4.901784  4.891901
# 2022-09-08  4.901784  4.882019  4.891901
# 2022-09-09  4.882019  4.862254  4.872136
# 2022-09-12  4.862254  4.921549  4.891901
# 2022-09-13  4.901784  4.921549  4.911667
# 2022-09-14  4.842488  4.862254  4.852371
# 2022-09-16  4.882019  4.882019  4.882019
# 2022-09-19  4.882019  4.862254  4.872136
# 2022-09-20  4.862253  4.882019  4.872136
# 2022-09-21  4.862254  4.862254  4.862254
# 2022-09-22  4.901784  4.862254  4.882019
# 2022-09-23  4.921549  4.862254  4.891902
# 2022-09-26  4.842488  4.862254  4.852371
# 2022-09-27  4.882019  4.901784  4.891901
# 2022-09-28  4.862254  4.842488  4.852371
# 2022-09-29  4.842488  4.882019  4.862253
# 2022-09-30  4.842488  4.862254  4.852371

# %% [markdown]
# ##### เดือน ตุลาคม [October]

# %%
mean_OCT_SCG = SCG.drop(columns=["High", "Low", "Volume"])
mean_OCT_SCG = mean_OCT_SCG["2022-10-01":"2022-10-31"]
# ถ้าพบว่ามี NaN อยู่ใน dataFrame ให้ drop ทั้ง row
mean_OCT_SCG = mean_OCT_SCG.dropna(how="any")
# เพิ่มคอลัมน์ที่คำนวณค่าเฉลี่ยของ Open และ Close
mean_OCT_SCG["Mean"] = (mean_OCT_SCG["Open"] + mean_OCT_SCG["Close"])/2
mean_OCT_SCG
# Out:
#                 Open     Close      Mean
# Date
# 2022-10-03  4.723897  4.802958  4.763428
# 2022-10-04  4.783193  4.842488  4.812840
# 2022-10-05  4.842488  4.842488  4.842488
# 2022-10-06  4.822723  4.822723  4.822723
# 2022-10-07  4.822723  4.882019  4.852371
